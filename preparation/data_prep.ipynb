# %%
import pandas as pd
import numpy as np
import re
import os

import nltk
from nltk.corpus import stopwords
from lemminflect import getLemma
import spacy

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
dataset = pd.read_csv('/content/raw_data.csv')
dataset.head()

# %%
df = pd.DataFrame()
df['review'] = dataset[['content']]
df.head()
# Out:
#                                               review
# 0  Ever since the update, there's a weird glitch ...
# 1  Don't believe the news!!! You can absolutely c...
# 2  Great app. Too many ads. If you saw a video an...
# 3  Good app, but there's a glitch that I've had i...
# 4  The creator of this app created an algorithm t...

# %%
df['review'] = df['review'].map(lambda x: str(x))

# %%
# Remove unicode
df['cleaned_review'] = df['review'].map(lambda x: x.encode('ascii', 'ignore').decode())
# Lower text
df['cleaned_review'] = df['cleaned_review'].map(lambda x: x.lower())
# Remove URL
df['cleaned_review'] = df['cleaned_review'].map(lambda x: re.sub(r'https?://\S+|www\.\S+', '', x))
# Remove number and special characters
df['cleaned_review'] = df['cleaned_review'].map(lambda x: re.sub(r'[^a-zA-Z]',' ',x))
# Remove extra whitespaces
df['cleaned_review'] = df['cleaned_review'].map(lambda x: re.sub(r'^\s*|\s\s*', ' ', x).strip())

# %%
df.head()
# Out:
#                                               review  \
# 0  Ever since the update, there's a weird glitch ...
# 1  Don't believe the news!!! You can absolutely c...
# 2  Great app. Too many ads. If you saw a video an...
# 3  Good app, but there's a glitch that I've had i...
# 4  The creator of this app created an algorithm t...
#
#                                       cleaned_review
# 0  ever since the update there s a weird glitch w...
# 1  don t believe the news you can absolutely cont...
# 2  great app too many ads if you saw a video and ...
# 3  good app but there s a glitch that i ve had is...
# 4  the creator of this app created an algorithm t...

# %%
# Tokenization

df['cleaned_review'] = df['cleaned_review'].map(lambda x: x.split())
df.head()
# Out:
#                                               review  \
# 0  Ever since the update, there's a weird glitch ...
# 1  Don't believe the news!!! You can absolutely c...
# 2  Great app. Too many ads. If you saw a video an...
# 3  Good app, but there's a glitch that I've had i...
# 4  The creator of this app created an algorithm t...
#
#                                       cleaned_review
# 0  [ever, since, ﻿the, update, there, a, a, weird...
# 1  [don, to, believe, ﻿the, news, you, can, absol...
# 2  [great, app, too, many, ads, if, you, saw, a, ...
# 3  [good, app, but, there, a, a, glitch, that, i,...
# 4  [﻿the, creator, of, this, app, created, an, al...

# %%
# Stopword Removal

stop_words = set(stopwords.words('english'))
df['cleaned_review'] = df['cleaned_review'].map(lambda x: [word for word in x if word not in stop_words])
df.head()
# Out:
#                                               review  \
# 0  Ever since the update, there's a weird glitch ...
# 1  Don't believe the news!!! You can absolutely c...
# 2  Great app. Too many ads. If you saw a video an...
# 3  Good app, but there's a glitch that I've had i...
# 4  The creator of this app created an algorithm t...
#
#                                       cleaned_review
# 0  [ever, since, ﻿the, update, weird, glitch, tur...
# 1  [believe, ﻿the, news, absolutely, control, app...
# 2  [great, app, many, ads, saw, video, lose, lost...
# 3  [good, app, glitch, issues, awhile, solution, ...
# 4  [﻿the, creator, app, created, algorithm, let, ...

# %%
# Lemmatization

nlp = spacy.load("en_core_web_sm")

def lemmatize_with_lemminflect(word, pos):
    lemma = getLemma(word, pos)
    if lemma:
        return lemma[0]
    else:
        return word

def lemmatize_text_with_lemminflect(text):
    doc = nlp(text)
    lemmatized_tokens = [lemmatize_with_lemminflect(token.text, token.pos_) for token in doc]
    return ' '.join(lemmatized_tokens)

df['cleaned_review'] = df['cleaned_review'].map(lambda x: lemmatize_text_with_lemminflect(' '.join(x)))

# %%
df
# Out:
#                                                   review  \
# 0      Ever since the update, there's a weird glitch ...
# 1      Don't believe the news!!! You can absolutely c...
# 2      Great app. Too many ads. If you saw a video an...
# 3      Good app, but there's a glitch that I've had i...
# 4      The creator of this app created an algorithm t...
# ...                                                  ...
# 14995  THIS IS THE BEST GAME EVER I PLAY THIS THE MOS...
# 14996  PLEASE FIX THIS GLITCH! So sometimes when I jo...
# 14997  i love roblox it is my favorite game to play b...
# 14998  This game is pretty cool but there is just one...
# 14999  Best game ive played for sure. Buttttttt.. rob...
#
#                                           cleaned_review
# 0      ever since update weird glitch turn subtitle e...
# 1      believe news absolutely control app access pho...
# 2      great app many ad see video lose lose forever ...
# 3      good app glitch issue awhile solution big save...
# 4      creator app create algorithm let choose well b...
# ...                                                  ...
# 14995  good game ever play idea make even good people...
# 14996  please fix glitch sometimes join game move jum...
# 14997  love roblox favorite game play wish will chang...
# 14998  game pretty cool one actually there s two prob...
# 14999  good game i ve play sure buttttttt robux price...
#
# [15000 rows x 2 columns]

# %%
df.to_csv('/content/preped_data_scrapped.csv', index=False)
